# %%
# Essentials
import numpy as np
import pandas as pd
import datetime
import random

# Plots
import seaborn as sns
import matplotlib.pyplot as plt

# Models
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.linear_model import ElasticNet, ElasticNetCV
from sklearn.svm import SVR
from mlxtend.regressor import StackingCVRegressor
import lightgbm as lgb
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor

# Stats
from scipy.stats import skew, norm
from scipy.special import boxcox1p
from scipy.stats import boxcox_normmax

# Misc
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.decomposition import PCA

pd.set_option('display.max_columns', None)

# Ignore useless warnings
import warnings
warnings.filterwarnings(action="ignore")
pd.options.display.max_seq_items = 8000
pd.options.display.max_rows = 8000

# %%
bp_file = '/mnt/volume1/T2D/EMR-data/OralGlucose.csv'
bp_file_p = '/mnt/volume1/T2D/EMR-data2/OralGlucose.csv'

# %%
data_pd = pd.read_csv(bp_file, sep='|')

# %%
len(data_pd), len(pd.Series(data_pd["Deidentified_Pat_ID"].tolist()).sort_values().unique())
# Out:
# (1649, 123)

# %%
data_pd.head()
# Out:
#   Deidentified_Pat_ID  ResultNum        Component          Result  \
# 0            ZHAZTNOZ          1  GLUCOSE FASTING              96
# 1            ZHAZTNOZ          1          FASTING             Yes
# 2            ZHAZTNOZ          1       DOSE GIVEN  100 gm Glucose
# 3            ZHAZTNOZ          1       TIME GIVEN         7:45 AM
# 4            ZHAZTNOZ          5     GLUCOSE 1 HR             178
#
#    ResultedYear
# 0          2014
# 1          2014
# 2          2014
# 3          2014
# 4          2014

# %%
pd.Series(data_pd["Component"].tolist()).sort_values().unique()
# Out:
# array(['DOSE GIVEN', 'FASTING', 'GLU TOL BEVERAGE DOSE',
#        'GLU TOL BEVERAGE EXP DATE', 'GLU TOL BEVERAGE LOT #',
#        'GLUCOSE 1 HR', 'GLUCOSE 2 HR', 'GLUCOSE 3 HR', 'GLUCOSE FASTING',
#        'HEMOLYSIS INDEX', 'ICTERIC INDEX', 'LIPEMIC INDEX', 'TIME GIVEN'],
#       dtype=object)

# %%
HEMOLYSIS_dt = data_pd[(data_pd['Component'] == 'HEMOLYSIS INDEX')]
HEMOLYSIS_dt = HEMOLYSIS_dt[(HEMOLYSIS_dt['Component'].notna())]
len(HEMOLYSIS_dt)
# Out:
# 278

# %%
len(data_pd[(data_pd['Component'] == 'HEMOLYSIS INDEX')])
# Out:
# 278

# %%
data_pd = data_pd[~(data_pd['Component'].isna())]
data_pd = data_pd[~(data_pd['Result'].isna())]
data_pd = data_pd[~(data_pd['Component'] == 'FASTING')]
data_pd = data_pd[~(data_pd['Component'] == 'DOSE GIVEN')]
data_pd = data_pd[~(data_pd['Component'] == 'TIME GIVEN')]
data_pd = data_pd[~(data_pd['Component'] == 'GLU TOL BEVERAGE EXP DATE')]
data_pd = data_pd[~(data_pd['Component'] == 'GLU TOL BEVERAGE DOSE')]
data_pd = data_pd[~(data_pd['Component'] == 'GLU TOL BEVERAGE LOT #')]

#data_pd = data_pd[~(data_pd['Component'] == 'HEMOLYSIS INDEX')]
#data_pd = data_pd[~(data_pd['Component'] == 'ICTERIC INDEX')]
#data_pd = data_pd[~(data_pd['Component'] == 'LIPEMIC INDEX')]

data_pd.reset_index(inplace=True)

data_pd.sort_values(["Deidentified_Pat_ID", "ResultedYear", 'Component'], inplace=True)

# %%
len(data_pd)
# Out:
# 739

# %%
sinlge_data1 = data_pd.drop_duplicates(["Deidentified_Pat_ID", "ResultedYear", 'Component'])
len(data_pd)
# Out:
# 739

# %%
data_pd[['Result']] = data_pd[['Result']].astype('float')
data_bp_mean1 = data_pd.groupby(['Deidentified_Pat_ID', 'ResultedYear', 'Component'])[['Result']].max()
data_bp_mean1.reset_index(inplace=True)
data_bp_mean1.head
# Out:
# <bound method NDFrame.head of     Deidentified_Pat_ID  ResultedYear        Component  Result
# 0              MNVHNHNZ          2015     GLUCOSE 1 HR   175.0
# 1              MNVHNHNZ          2015     GLUCOSE 2 HR   142.0
# 2              MNVHNHNZ          2015     GLUCOSE 3 HR   125.0
# 3              MNVHNHNZ          2015  GLUCOSE FASTING    87.0
# 4              MNVHNHNZ          2016     GLUCOSE 1 HR   144.0
# 5              MNVHNHNZ          2016     GLUCOSE 2 HR   100.0
# 6              MNVHNHNZ          2016     GLUCOSE 3 HR    97.0
# 7              MNVHNHNZ          2016  GLUCOSE FASTING    88.0
# 8                ZADTOK          2016     GLUCOSE 2 HR    74.0
# 9                ZADTOK          2016  GLUCOSE FASTING    90.0
# 10               ZADTOK          2016  HEMOLYSIS INDEX    15.0
# 11               ZADTOK          2016    ICTERIC INDEX     2.0
# 12               ZADTOK          2016    LIPEMIC INDEX    20.0
# 13              ZAVKNHD          2017     GLUCOSE 1 HR    84.0
# 14              ZAVKNHD          2017     GLUCOSE 2 HR   119.0
# 15              ZAVKNHD          2017     GLUCOSE 3 HR    81.0
# 16              ZAVKNHD          2017  GLUCOSE FASTING    79.0
# 17              ZAVOOHT          2014     GLUCOSE 1 HR   166.0
# 18              ZAVOOHT          2014     GLUCOSE 2 HR   157.0
# 19              ZAVOOHT          2014     GLUCOSE 3 HR    86.0
# 20              ZAVOOHT          2014  GLUCOSE FASTING    82.0
# 21              ZAVOOHT          2015     GLUCOSE 1 HR   175.0
# 22              ZAVOOHT          2015     GLUCOSE 2 HR   155.0
# 23              ZAVOOHT          2015     GLUCOSE 3 HR   107.0
# 24              ZAVOOHT          2015  GLUCOSE FASTING    90.0
# 25              ZAVOOHT          2018     GLUCOSE 1 HR   160.0
# 26              ZAVOOHT          2018     GLUCOSE 2 HR   165.0
# 27              ZAVOOHT          2018     GLUCOSE 3 HR   131.0
# 28              ZAVOOHT          2018  GLUCOSE FASTING    81.0
# 29              ZDAKGNH          2015     GLUCOSE 2 HR   172.0
# 30              ZDAKGNH          2015  GLUCOSE FASTING    87.0
# 31             ZDDAADOA          2015     GLUCOSE 1 HR   147.0
# 32             ZDDAADOA          2015     GLUCOSE 2 HR   135.0
# 33             ZDDAADOA          2015     GLUCOSE 3 HR   140.0
# 34             ZDDAADOA          2015  GLUCOSE FASTING    88.0
# 35             ZDDANAGH          2014     GLUCOSE 2 HR    86.0
# 36             ZDDANAGH          2014  GLUCOSE FASTING    86.0
# 37             ZDDGKAAH          2015     GLUCOSE 2 HR    88.0
# 38             ZDDGKAAH          2015  GLUCOSE FASTING   100.0
# 39               ZDDHAD          2015     GLUCOSE 1 HR   147.0
# 40               ZDDHAD          2015     GLUCOSE 2 HR   142.0
# 41               ZDDHAD          2015     GLUCOSE 3 HR   123.0
# 42               ZDDHAD          2015  GLUCOSE FASTING    77.0
# 43             ZDDKAGTG          2018     GLUCOSE 2 HR   131.0
# 44             ZDDKAGTG          2018  GLUCOSE FASTING    97.0
# 45             ZDDKHGDO          2018     GLUCOSE 1 HR   182.0
# 46             ZDDKHGDO          2018     GLUCOSE 2 HR   123.0
# 47             ZDDKHGDO          2018     GLUCOSE 3 HR   117.0
# 48             ZDDKHGDO          2018  GLUCOSE FASTING    89.0
# 49             ZDDKZDGA          2015     GLUCOSE 1 HR   212.0
# 50             ZDDKZDGA          2015     GLUCOSE 2 HR   152.0
# 51             ZDDKZDGA          2015     GLUCOSE 3 HR    97.0
# 52             ZDDKZDGA          2015  GLUCOSE FASTING   109.0
# 53             ZDDKZDGA          2016     GLUCOSE 2 HR   108.0
# 54             ZDDKZDGA          2016  GLUCOSE FASTING    99.0
# 55               ZDDONZ          2016     GLUCOSE 2 HR   138.0
# 56               ZDDONZ          2016  GLUCOSE FASTING    87.0
# 57             ZDDZTDHD          2017     GLUCOSE 2 HR    91.0
# 58             ZDDZTDHD          2017  GLUCOSE FASTING    81.0
# 59             ZDGAZAVH          2016     GLUCOSE 1 HR   223.0
# 60             ZDGAZAVH          2016     GLUCOSE 2 HR   160.0
# 61             ZDGAZAVH          2016     GLUCOSE 3 HR   145.0
# 62             ZDGAZAVH          2016  GLUCOSE FASTING    94.0
# 63             ZDGAZAVH          2016  HEMOLYSIS INDEX     3.0
# 64             ZDGAZAVH          2016    ICTERIC INDEX     0.0
# 65             ZDGAZAVH          2016    LIPEMIC INDEX    21.0
# 66             ZDGKVNTH          2017     GLUCOSE 1 HR   153.0
# 67             ZDGKVNTH          2017     GLUCOSE 2 HR   136.0
# 68             ZDGKVNTH          2017     GLUCOSE 3 HR    47.0
# 69             ZDGKVNTH          2017  GLUCOSE FASTING    72.0
# 70             ZDGNZKND          2016     GLUCOSE 1 HR   149.0
# 71             ZDGNZKND          2016     GLUCOSE 2 HR   129.0
# 72             ZDGNZKND          2016     GLUCOSE 3 HR   110.0
# 73             ZDGNZKND          2016  GLUCOSE FASTING    88.0
# 74             ZDGNZKND          2016  HEMOLYSIS INDEX    23.0
# 75             ZDGNZKND          2016    ICTERIC INDEX     1.0
# 76             ZDGNZKND          2016    LIPEMIC INDEX    12.0
# 77              ZDGONOH          2014     GLUCOSE 2 HR    46.0
# 78              ZDGONOH          2014  GLUCOSE FASTING    91.0
# 79              ZDGZGVZ          2017     GLUCOSE 2 HR    76.0
# 80              ZDGZGVZ          2017  GLUCOSE FASTING    82.0
# 81              ZDHDVNV          2017     GLUCOSE 1 HR   197.0
# 82              ZDHDVNV          2017  GLUCOSE FASTING   110.0
# 83              ZDHONAK          2016     GLUCOSE 1 HR   139.0
# 84              ZDHONAK          2016     GLUCOSE 2 HR   123.0
# 85              ZDHONAK          2016     GLUCOSE 3 HR   113.0
# 86              ZDHONAK          2016  GLUCOSE FASTING    72.0
# 87             ZDHTHKZG          2018     GLUCOSE 2 HR   103.0
# 88             ZDHTHKZG          2018  GLUCOSE FASTING    99.0
# 89             ZDHVZDAV          2018     GLUCOSE 2 HR   223.0
# 90             ZDHVZDAV          2018  GLUCOSE FASTING   118.0
# 91             ZDKGHTDV          2016     GLUCOSE 1 HR   188.0
# 92             ZDKGHTDV          2016     GLUCOSE 2 HR   141.0
# 93             ZDKGHTDV          2016     GLUCOSE 3 HR   125.0
# 94             ZDKGHTDV          2016  GLUCOSE FASTING    96.0
# 95             ZDKNTDAA          2016     GLUCOSE 2 HR   167.0
# 96             ZDKNTDAA          2016  GLUCOSE FASTING   107.0
# 97              ZDNDKVD          2015     GLUCOSE 1 HR   154.0
# 98              ZDNDKVD          2015     GLUCOSE 2 HR   147.0
# 99              ZDNDKVD          2015     GLUCOSE 3 HR   115.0
# 100             ZDNDKVD          2015  GLUCOSE FASTING    80.0
# 101             ZDNDKVD          2017     GLUCOSE 1 HR   150.0
# 102             ZDNDKVD          2017     GLUCOSE 2 HR   129.0
# 103             ZDNDKVD          2017     GLUCOSE 3 HR   122.0
# 104             ZDNDKVD          2017  GLUCOSE FASTING    86.0
# 105              ZDNKZH          2017     GLUCOSE 1 HR   206.0
# 106              ZDNKZH          2017     GLUCOSE 2 HR   216.0
# 107              ZDNKZH          2017     GLUCOSE 3 HR    99.0
# 108              ZDNKZH          2017  GLUCOSE FASTING   107.0
# 109            ZDOGDAOO          2015     GLUCOSE 1 HR   122.0
# 110            ZDOGDAOO          2015     GLUCOSE 2 HR    94.0
# 111            ZDOGDAOO          2015     GLUCOSE 3 HR    75.0
# 112            ZDOGDAOO          2015  GLUCOSE FASTING    96.0
# 113            ZDOGKKTZ          2014     GLUCOSE 1 HR   184.0
# 114            ZDOGKKTZ          2014     GLUCOSE 2 HR   175.0
# 115            ZDOGKKTZ          2014     GLUCOSE 3 HR   120.0
# 116            ZDOGKKTZ          2014  GLUCOSE FASTING   105.0
# 117            ZDOGKKTZ          2015     GLUCOSE 1 HR   188.0
# 118            ZDOGKKTZ          2015     GLUCOSE 2 HR   134.0
# 119            ZDOGKKTZ          2015     GLUCOSE 3 HR   108.0
# 120            ZDOGKKTZ          2015  GLUCOSE FASTING    91.0
# 121            ZDOHOADT          2014     GLUCOSE 1 HR   178.0
# 122            ZDOHOADT          2014     GLUCOSE 2 HR   143.0
# 123            ZDOHOADT          2014     GLUCOSE 3 HR   112.0
# 124            ZDOHOADT          2014  GLUCOSE FASTING    90.0
# 125             ZDOTGZD          2017     GLUCOSE 2 HR    69.0
# 126             ZDOTGZD          2017  GLUCOSE FASTING   119.0
# 127             ZDOTGZD          2019     GLUCOSE 2 HR    99.0
# 128             ZDOTGZD          2019  GLUCOSE FASTING    97.0
# 129            ZDTHDNKH          2016     GLUCOSE 1 HR   163.0
# 130            ZDTHDNKH          2016     GLUCOSE 2 HR   154.0
# 131            ZDTHDNKH          2016     GLUCOSE 3 HR    84.0
# 132            ZDTHDNKH          2016  GLUCOSE FASTING    80.0
# 133            ZDTHDNKH          2018     GLUCOSE 1 HR   199.0
# 134            ZDTHDNKH          2018     GLUCOSE 2 HR   162.0
# 135            ZDTHDNKH          2018     GLUCOSE 3 HR    75.0
# 136            ZDTHDNKH          2018  GLUCOSE FASTING    97.0
# 137            ZDVDKVON          2018     GLUCOSE 1 HR   141.0
# 138            ZDVDKVON          2018     GLUCOSE 2 HR   124.0
# 139            ZDVDKVON          2018     GLUCOSE 3 HR    88.0
# 140            ZDVDKVON          2018  GLUCOSE FASTING    80.0
# 141              ZDVGNG          2017     GLUCOSE 2 HR   164.0
# 142              ZDVGNG          2017  GLUCOSE FASTING   109.0
# 143            ZDVHOTKN          2016     GLUCOSE 1 HR   145.0
# 144            ZDVHOTKN          2016     GLUCOSE 2 HR   120.0
# 145            ZDVHOTKN          2016     GLUCOSE 3 HR   114.0
# 146            ZDVHOTKN          2016  GLUCOSE FASTING    84.0
# 147            ZDVKVGKV          2018     GLUCOSE 1 HR   185.0
# 148            ZDVKVGKV          2018     GLUCOSE 2 HR   111.0
# 149            ZDVKVGKV          2018     GLUCOSE 3 HR   117.0
# 150            ZDVKVGKV          2018  GLUCOSE FASTING    94.0
# 151            ZDVNGGNZ          2018     GLUCOSE 2 HR    99.0
# 152            ZDVNGGNZ          2018  GLUCOSE FASTING    84.0
# 153             ZDVOZZT          2015     GLUCOSE 1 HR   166.0
# 154             ZDVOZZT          2015     GLUCOSE 2 HR   182.0
# 155             ZDVOZZT          2015     GLUCOSE 3 HR    81.0
# 156             ZDVOZZT          2015  GLUCOSE FASTING    87.0
# 157            ZDVVKNOO          2019     GLUCOSE 2 HR   117.0
# 158            ZDVVKNOO          2019  GLUCOSE FASTING    90.0
# 159             ZDZDNTH          2015     GLUCOSE 1 HR   165.0
# 160             ZDZDNTH          2015     GLUCOSE 2 HR   134.0
# 161             ZDZDNTH          2015     GLUCOSE 3 HR    70.0
# 162             ZDZDNTH          2015  GLUCOSE FASTING    83.0
# 163            ZDZDOKGV          2016     GLUCOSE 2 HR    91.0
# 164            ZDZDOKGV          2016  GLUCOSE FASTING   105.0
# 165            ZDZHNDNK          2017     GLUCOSE 2 HR    95.0
# 166            ZDZHNDNK          2017  GLUCOSE FASTING    89.0
# 167            ZDZOKTOD          2015     GLUCOSE 1 HR   152.0
# 168            ZDZOKTOD          2015     GLUCOSE 2 HR   165.0
# 169            ZDZOKTOD          2015     GLUCOSE 3 HR   126.0
# 170            ZDZOKTOD          2015  GLUCOSE FASTING    77.0
# 171            ZDZOKTOD          2018     GLUCOSE 1 HR   178.0
# 172            ZDZOKTOD          2018     GLUCOSE 2 HR   157.0
# 173            ZDZOKTOD          2018     GLUCOSE 3 HR   125.0
# 174            ZDZOKTOD          2018  GLUCOSE FASTING    83.0
# 175            ZDZOKTOD          2018  HEMOLYSIS INDEX     5.0
# 176            ZDZOKTOD          2018    ICTERIC INDEX     1.0
# 177            ZDZOKTOD          2018    LIPEMIC INDEX    13.0
# 178            ZDZTDNNK          2015     GLUCOSE 2 HR   130.0
# 179            ZDZTDNNK          2015  GLUCOSE FASTING   110.0
# 180            ZDZVKGHD          2015     GLUCOSE 1 HR   166.0
# 181            ZDZVKGHD          2015     GLUCOSE 2 HR   187.0
# 182            ZDZVKGHD          2015     GLUCOSE 3 HR   120.0
# 183            ZDZVKGHD          2015  GLUCOSE FASTING    86.0
# 184            ZDZZHTHV          2015     GLUCOSE 1 HR   174.0
# 185            ZDZZHTHV          2015     GLUCOSE 2 HR   188.0
# 186            ZDZZHTHV          2015     GLUCOSE 3 HR   114.0
# 187            ZDZZHTHV          2015  GLUCOSE FASTING    82.0
# 188            ZDZZVVKG          2017     GLUCOSE 1 HR   175.0
# 189            ZDZZVVKG          2017     GLUCOSE 2 HR   207.0
# 190            ZDZZVVKG          2017     GLUCOSE 3 HR   185.0
# 191            ZDZZVVKG          2017  GLUCOSE FASTING   124.0
# 192              ZGNGAT          2017     GLUCOSE 1 HR   181.0
# 193              ZGNGAT          2017     GLUCOSE 2 HR   154.0
# 194              ZGNGAT          2017     GLUCOSE 3 HR   158.0
# 195              ZGNGAT          2017  GLUCOSE FASTING    94.0
# 196              ZGNGAT          2017  HEMOLYSIS INDEX    15.0
# 197              ZGNGAT          2017    ICTERIC INDEX     2.0
# 198              ZGNGAT          2017    LIPEMIC INDEX    20.0
# 199             ZGTDNTA          2018     GLUCOSE 2 HR    90.0
# 200             ZGTDNTA          2018  GLUCOSE FASTING    93.0
# 201            ZHAKAKNO          2019     GLUCOSE 1 HR   180.0
# 202            ZHAKAKNO          2019     GLUCOSE 2 HR   121.0
# 203            ZHAKAKNO          2019     GLUCOSE 3 HR    55.0
# 204            ZHAKAKNO          2019  GLUCOSE FASTING    85.0
# 205            ZHAKAKNO          2019  HEMOLYSIS INDEX     2.0
# 206            ZHAKAKNO          2019    ICTERIC INDEX     1.0
# 207            ZHAKAKNO          2019    LIPEMIC INDEX    10.0
# 208            ZHATVNOK          2017     GLUCOSE 2 HR    79.0
# 209            ZHATVNOK          2017  GLUCOSE FASTING   106.0
# 210            ZHAVGHHV          2014     GLUCOSE 1 HR   129.0
# 211            ZHAVGHHV          2014     GLUCOSE 2 HR   138.0
# 212            ZHAVGHHV          2014     GLUCOSE 3 HR   121.0
# 213            ZHAVGHHV          2014  GLUCOSE FASTING    82.0
# 214            ZHAZGKHZ          2015     GLUCOSE 1 HR   147.0
# 215            ZHAZGKHZ          2015     GLUCOSE 2 HR   141.0
# 216            ZHAZGKHZ          2015     GLUCOSE 3 HR   119.0
# 217            ZHAZGKHZ          2015  GLUCOSE FASTING    83.0
# 218            ZHAZGZNH          2017     GLUCOSE 1 HR   157.0
# 219            ZHAZGZNH          2017     GLUCOSE 2 HR   154.0
# 220            ZHAZGZNH          2017     GLUCOSE 3 HR   126.0
# 221            ZHAZGZNH          2017  GLUCOSE FASTING    83.0
# 222            ZHAZTNOZ          2014     GLUCOSE 1 HR   178.0
# 223            ZHAZTNOZ          2014     GLUCOSE 2 HR   136.0
# 224            ZHAZTNOZ          2014     GLUCOSE 3 HR   110.0
# 225            ZHAZTNOZ          2014  GLUCOSE FASTING    96.0
# 226             ZHDNDNG          2018     GLUCOSE 1 HR   196.0
# 227             ZHDNDNG          2018     GLUCOSE 2 HR   178.0
# 228             ZHDNDNG          2018     GLUCOSE 3 HR    61.0
# 229             ZHDNDNG          2018  GLUCOSE FASTING    71.0
# 230             ZHDONKV          2017     GLUCOSE 1 HR   191.0
# 231             ZHDONKV          2017     GLUCOSE 2 HR   173.0
# 232             ZHDONKV          2017     GLUCOSE 3 HR    46.0
# 233             ZHDONKV          2017  GLUCOSE FASTING    76.0
# 234             ZHDTHZV          2015     GLUCOSE 1 HR   185.0
# 235             ZHDTHZV          2015     GLUCOSE 2 HR   160.0
# 236             ZHDTHZV          2015     GLUCOSE 3 HR   128.0
# 237             ZHDTHZV          2015  GLUCOSE FASTING    89.0
# 238            ZHDTTTOA          2015     GLUCOSE 1 HR   207.0
# 239            ZHDTTTOA          2015     GLUCOSE 2 HR   158.0
# 240            ZHDTTTOA          2015     GLUCOSE 3 HR   104.0
# 241            ZHDTTTOA          2015  GLUCOSE FASTING   103.0
# 242            ZHDZNVKV          2014     GLUCOSE 1 HR   195.0
# 243            ZHDZNVKV          2014     GLUCOSE 2 HR   171.0
# 244            ZHDZNVKV          2014     GLUCOSE 3 HR   132.0
# 245            ZHDZNVKV          2014  GLUCOSE FASTING    86.0
# 246            ZHGANDHT          2016     GLUCOSE 1 HR   175.0
# 247            ZHGANDHT          2016     GLUCOSE 2 HR   134.0
# 248            ZHGANDHT          2016     GLUCOSE 3 HR   131.0
# 249            ZHGANDHT          2016  GLUCOSE FASTING    80.0
# 250            ZHGHTGKV          2015     GLUCOSE 1 HR   154.0
# 251            ZHGHTGKV          2015     GLUCOSE 2 HR   142.0
# 252            ZHGHTGKV          2015     GLUCOSE 3 HR    92.0
# 253            ZHGHTGKV          2015  GLUCOSE FASTING    91.0
# 254            ZHGOTVAK          2019     GLUCOSE 2 HR   100.0
# 255            ZHGOTVAK          2019  GLUCOSE FASTING    98.0
# 256             ZHGOTVG          2014     GLUCOSE 2 HR    87.0
# 257             ZHGOTVG          2014  GLUCOSE FASTING    88.0
# 258             ZHGOTVG          2016     GLUCOSE 1 HR   130.0
# 259             ZHGOTVG          2016     GLUCOSE 2 HR   120.0
# 260             ZHGOTVG          2016     GLUCOSE 3 HR    62.0
# 261             ZHGOTVG          2016  GLUCOSE FASTING    83.0
# 262            ZHGTTNKN          2017     GLUCOSE 1 HR   170.0
# 263            ZHGTTNKN          2017     GLUCOSE 2 HR   187.0
# 264            ZHGTTNKN          2017     GLUCOSE 3 HR   112.0
# 265            ZHGTTNKN          2017  GLUCOSE FASTING    86.0
# 266            ZHGTTNKN          2017  HEMOLYSIS INDEX    10.0
# 267            ZHGTTNKN          2017    ICTERIC INDEX     1.0
# 268            ZHGTTNKN          2017    LIPEMIC INDEX    15.0
# 269            ZHGTTNKN          2018     GLUCOSE 1 HR   170.0
# 270            ZHGTTNKN          2018     GLUCOSE 2 HR   153.0
# 271            ZHGTTNKN          2018     GLUCOSE 3 HR   129.0
# 272            ZHGTTNKN          2018  GLUCOSE FASTING    84.0
# 273            ZHGTTNKN          2018  HEMOLYSIS INDEX    11.0
# 274            ZHGTTNKN          2018    ICTERIC INDEX     1.0
# 275            ZHGTTNKN          2018    LIPEMIC INDEX    13.0
# 276            ZHGTZOGO          2018     GLUCOSE 1 HR   159.0
# 277            ZHGTZOGO          2018     GLUCOSE 2 HR   133.0
# 278            ZHGTZOGO          2018     GLUCOSE 3 HR    94.0
# 279            ZHGTZOGO          2018  GLUCOSE FASTING    82.0
# 280            ZHGVOTAO          2015     GLUCOSE 1 HR   218.0
# 281            ZHGVOTAO          2015     GLUCOSE 2 HR   139.0
# 282            ZHGVOTAO          2015     GLUCOSE 3 HR   118.0
# 283            ZHGVOTAO          2015  GLUCOSE FASTING   102.0
# 284            ZHGVTTKT          2014     GLUCOSE 2 HR   145.0
# 285            ZHGVTTKT          2014  GLUCOSE FASTING   135.0
# 286            ZHHGDTDH          2017     GLUCOSE 1 HR   101.0
# 287            ZHHGDTDH          2017     GLUCOSE 2 HR    96.0
# 288            ZHHGDTDH          2017     GLUCOSE 3 HR    79.0
# 289            ZHHGDTDH          2017  GLUCOSE FASTING    89.0
# 290              ZHHOAH          2018     GLUCOSE 1 HR   163.0
# 291              ZHHOAH          2018     GLUCOSE 2 HR   152.0
# 292              ZHHOAH          2018     GLUCOSE 3 HR    94.0
# 293              ZHHOAH          2018  GLUCOSE FASTING    79.0
# 294            ZHHOVHVO          2018     GLUCOSE 1 HR   155.0
# 295            ZHHOVHVO          2018     GLUCOSE 2 HR   132.0
# 296            ZHHOVHVO          2018     GLUCOSE 3 HR   109.0
# 297            ZHHOVHVO          2018  GLUCOSE FASTING    88.0
# 298            ZHHVZKDV          2015     GLUCOSE 1 HR   206.0
# 299            ZHHVZKDV          2015     GLUCOSE 2 HR   157.0
# 300            ZHHVZKDV          2015     GLUCOSE 3 HR   132.0
# 301            ZHHVZKDV          2015  GLUCOSE FASTING    97.0
# 302            ZHKAKGTG          2017     GLUCOSE 2 HR   105.0
# 303            ZHKAKGTG          2017  GLUCOSE FASTING    93.0
# 304            ZHKONOZG          2017     GLUCOSE 2 HR   191.0
# 305            ZHKONOZG          2017  GLUCOSE FASTING   103.0
# 306            ZHKZGHGZ          2016     GLUCOSE 1 HR   167.0
# 307            ZHKZGHGZ          2016     GLUCOSE 2 HR    85.0
# 308            ZHKZGHGZ          2016     GLUCOSE 3 HR   114.0
# 309            ZHKZGHGZ          2016  GLUCOSE FASTING    77.0
# 310            ZHKZGHGZ          2019     GLUCOSE 1 HR   166.0
# 311            ZHKZGHGZ          2019     GLUCOSE 2 HR   144.0
# 312            ZHKZGHGZ          2019     GLUCOSE 3 HR    62.0
# 313            ZHKZGHGZ          2019  GLUCOSE FASTING    81.0
# 314            ZHKZGHGZ          2019  HEMOLYSIS INDEX     6.0
# 315            ZHKZGHGZ          2019    ICTERIC INDEX     1.0
# 316            ZHKZGHGZ          2019    LIPEMIC INDEX     9.0
# 317            ZHNAGOKZ          2018     GLUCOSE 1 HR   170.0
# 318            ZHNAGOKZ          2018     GLUCOSE 2 HR   157.0
# 319            ZHNAGOKZ          2018     GLUCOSE 3 HR   149.0
# 320            ZHNAGOKZ          2018  GLUCOSE FASTING    80.0
# 321            ZHNOHGNA          2019     GLUCOSE 2 HR   127.0
# 322            ZHNOHGNA          2019  GLUCOSE FASTING    90.0
# 323            ZHNOHGNA          2019  HEMOLYSIS INDEX     2.0
# 324            ZHNOHGNA          2019    ICTERIC INDEX     0.0
# 325            ZHNOHGNA          2019    LIPEMIC INDEX    -3.0
# 326            ZHOAVHVH          2014     GLUCOSE 1 HR   174.0
# 327            ZHOAVHVH          2014     GLUCOSE 2 HR   173.0
# 328            ZHOAVHVH          2014     GLUCOSE 3 HR   134.0
# 329            ZHOAVHVH          2014  GLUCOSE FASTING    87.0
# 330            ZHOGNAKG          2014     GLUCOSE 2 HR   101.0
# 331            ZHOHDTOV          2018     GLUCOSE 2 HR   130.0
# 332            ZHOHDTOV          2018  GLUCOSE FASTING    94.0
# 333            ZHOHNTKD          2014     GLUCOSE 2 HR   125.0
# 334            ZHOHNTKD          2014  GLUCOSE FASTING    91.0
# 335            ZHTGVDZV          2016     GLUCOSE 1 HR   221.0
# 336            ZHTGVDZV          2016     GLUCOSE 2 HR   217.0
# 337            ZHTGVDZV          2016     GLUCOSE 3 HR   114.0
# 338            ZHTGVDZV          2016  GLUCOSE FASTING   100.0
# 339            ZHTGVDZV          2017     GLUCOSE 2 HR   193.0
# 340            ZHTGVDZV          2017  GLUCOSE FASTING    99.0
# 341            ZHTHGZVT          2019     GLUCOSE 2 HR    65.0
# 342            ZHTHGZVT          2019  GLUCOSE FASTING    79.0
# 343            ZHTNHGKK          2014     GLUCOSE 1 HR   162.0
# 344            ZHTNHGKK          2014     GLUCOSE 2 HR   110.0
# 345            ZHTNHGKK          2014     GLUCOSE 3 HR   130.0
# 346            ZHTNHGKK          2014  GLUCOSE FASTING    82.0
# 347            ZHTONONO          2016     GLUCOSE 1 HR   114.0
# 348            ZHTONONO          2016     GLUCOSE 2 HR   135.0
# 349            ZHTONONO          2016     GLUCOSE 3 HR   101.0
# 350            ZHTONONO          2016  GLUCOSE FASTING    75.0
# 351            ZHTONONO          2016  HEMOLYSIS INDEX    12.0
# 352            ZHTONONO          2016    ICTERIC INDEX     1.0
# 353            ZHTONONO          2016    LIPEMIC INDEX    13.0
# 354            ZHTZNAZO          2016     GLUCOSE 1 HR   118.0
# 355            ZHTZNAZO          2016     GLUCOSE 2 HR   102.0
# 356            ZHTZNAZO          2016     GLUCOSE 3 HR    81.0
# 357            ZHTZNAZO          2016  GLUCOSE FASTING    84.0
# 358            ZHTZOOZZ          2017     GLUCOSE 1 HR   108.0
# 359            ZHTZOOZZ          2017     GLUCOSE 2 HR    92.0
# 360            ZHTZOOZZ          2017     GLUCOSE 3 HR    90.0
# 361            ZHTZOOZZ          2017  GLUCOSE FASTING    76.0
# 362            ZHZDNZAH          2016     GLUCOSE 2 HR   105.0
# 363            ZHZDNZAH          2016  GLUCOSE FASTING    93.0
# 364            ZHZGVNVK          2018     GLUCOSE 2 HR   107.0
# 365            ZHZGVNVK          2018  GLUCOSE FASTING    95.0
# 366            ZHZZZZNG          2017     GLUCOSE 1 HR   178.0
# 367            ZHZZZZNG          2017     GLUCOSE 2 HR   144.0
# 368            ZHZZZZNG          2017     GLUCOSE 3 HR    53.0
# 369            ZHZZZZNG          2017  GLUCOSE FASTING    96.0
# 370               ZKHHG          2015     GLUCOSE 1 HR   203.0
# 371               ZKHHG          2015     GLUCOSE 2 HR   166.0
# 372               ZKHHG          2015     GLUCOSE 3 HR   103.0
# 373               ZKHHG          2015  GLUCOSE FASTING    83.0
# 374              ZKNGOA          2019     GLUCOSE 2 HR   158.0
# 375              ZKNGOA          2019  GLUCOSE FASTING   105.0
# 376              ZKNGOA          2019  HEMOLYSIS INDEX     1.0
# 377              ZKNGOA          2019    ICTERIC INDEX     1.0
# 378              ZKNGOA          2019    LIPEMIC INDEX    11.0
# 379             ZKTKZNO          2016     GLUCOSE 2 HR    99.0
# 380             ZKTKZNO          2016  GLUCOSE FASTING   101.0
# 381            ZNKADOTD          2017     GLUCOSE 1 HR   179.0
# 382            ZNKADOTD          2017     GLUCOSE 2 HR   147.0
# 383            ZNKADOTD          2017     GLUCOSE 3 HR    98.0
# 384            ZNKADOTD          2017  GLUCOSE FASTING    83.0
# 385            ZNOZVVOV          2017     GLUCOSE 1 HR    90.0
# 386            ZNOZVVOV          2017     GLUCOSE 2 HR   101.0
# 387            ZNOZVVOV          2017     GLUCOSE 3 HR    77.0
# 388            ZNOZVVOV          2017  GLUCOSE FASTING    84.0
# 389            ZNOZVVOV          2017  HEMOLYSIS INDEX     6.0
# 390            ZNOZVVOV          2017    ICTERIC INDEX     1.0
# 391            ZNOZVVOV          2017    LIPEMIC INDEX     8.0
# 392            ZNTAKTHN          2016     GLUCOSE 1 HR   182.0
# 393            ZNTAKTHN          2016     GLUCOSE 2 HR   159.0
# 394            ZNTAKTHN          2016     GLUCOSE 3 HR   108.0
# 395            ZNTAKTHN          2016  GLUCOSE FASTING    87.0
# 396            ZNTAKTHN          2016  HEMOLYSIS INDEX    19.0
# 397            ZNTAKTHN          2016    ICTERIC INDEX     1.0
# 398            ZNTAKTHN          2016    LIPEMIC INDEX    10.0
# 399             ZOGKTVZ          2015     GLUCOSE 1 HR   177.0
# 400             ZOGKTVZ          2015     GLUCOSE 2 HR   148.0
# 401             ZOGKTVZ          2015     GLUCOSE 3 HR    77.0
# 402             ZOGKTVZ          2015  GLUCOSE FASTING    85.0
# 403              ZOTKDV          2016     GLUCOSE 1 HR   139.0
# 404              ZOTKDV          2016     GLUCOSE 2 HR   159.0
# 405              ZOTKDV          2016     GLUCOSE 3 HR   167.0
# 406              ZOTKDV          2016  GLUCOSE FASTING    79.0
# 407              ZOTKDV          2017     GLUCOSE 2 HR    81.0
# 408              ZOTKDV          2017  GLUCOSE FASTING    80.0
# 409                ZOVN          2016     GLUCOSE 1 HR   193.0
# 410                ZOVN          2016     GLUCOSE 2 HR   157.0
# 411                ZOVN          2016     GLUCOSE 3 HR   132.0
# 412                ZOVN          2016  GLUCOSE FASTING    89.0
# 413             ZTDDGAZ          2014     GLUCOSE 1 HR   179.0
# 414             ZTDDGAZ          2014     GLUCOSE 2 HR   168.0
# 415             ZTDDGAZ          2014     GLUCOSE 3 HR    83.0
# 416             ZTDDGAZ          2014  GLUCOSE FASTING    73.0
# 417             ZTDGNKO          2016     GLUCOSE 1 HR   170.0
# 418             ZTDGNKO          2016     GLUCOSE 2 HR   179.0
# 419             ZTDGNKO          2016     GLUCOSE 3 HR    69.0
# 420             ZTDGNKO          2016  GLUCOSE FASTING    90.0
# 421             ZTDGNKO          2019     GLUCOSE 1 HR   159.0
# 422             ZTDGNKO          2019     GLUCOSE 2 HR   169.0
# 423             ZTDGNKO          2019     GLUCOSE 3 HR    70.0
# 424             ZTDGNKO          2019  GLUCOSE FASTING    79.0
# 425             ZTGTZKH          2018     GLUCOSE 1 HR   177.0
# 426             ZTGTZKH          2018     GLUCOSE 2 HR   142.0
# 427             ZTGTZKH          2018     GLUCOSE 3 HR   141.0
# 428             ZTGTZKH          2018  GLUCOSE FASTING    91.0
# 429             ZTGTZKH          2018  HEMOLYSIS INDEX    11.0
# 430             ZTGTZKH          2018    ICTERIC INDEX     1.0
# 431             ZTGTZKH          2018    LIPEMIC INDEX     5.0
# 432             ZTTAZTK          2016     GLUCOSE 1 HR   201.0
# 433             ZTTAZTK          2016     GLUCOSE 2 HR   171.0
# 434             ZTTAZTK          2016     GLUCOSE 3 HR   138.0
# 435             ZTTAZTK          2016  GLUCOSE FASTING   111.0
# 436             ZTTAZTK          2017     GLUCOSE 2 HR   153.0
# 437             ZTTAZTK          2017  GLUCOSE FASTING    97.0
# 438             ZTTAZTK          2017  HEMOLYSIS INDEX    15.0
# 439             ZTTAZTK          2017    ICTERIC INDEX     2.0
# 440             ZTTAZTK          2017    LIPEMIC INDEX    20.0
# 441             ZZADNVG          2015     GLUCOSE 1 HR   158.0
# 442             ZZADNVG          2015     GLUCOSE 2 HR   148.0
# 443             ZZADNVG          2015     GLUCOSE 3 HR   121.0
# 444             ZZADNVG          2015  GLUCOSE FASTING    76.0
# 445              ZZAHTK          2016     GLUCOSE 1 HR   148.0
# 446              ZZAHTK          2016     GLUCOSE 2 HR   107.0
# 447              ZZAHTK          2016     GLUCOSE 3 HR   122.0
# 448              ZZAHTK          2016  GLUCOSE FASTING    66.0
# 449            ZZAKDNAA          2016     GLUCOSE 1 HR   185.0
# 450            ZZAKDNAA          2016     GLUCOSE 2 HR   174.0
# 451            ZZAKDNAA          2016     GLUCOSE 3 HR   145.0
# 452            ZZAKDNAA          2016  GLUCOSE FASTING   101.0
# 453            ZZAKDNAA          2016  HEMOLYSIS INDEX     6.0
# 454            ZZAKDNAA          2016    ICTERIC INDEX     1.0
# 455            ZZAKDNAA          2016    LIPEMIC INDEX    40.0
# 456             ZZATDNN          2015     GLUCOSE 1 HR   188.0
# 457             ZZATDNN          2015     GLUCOSE 2 HR   154.0
# 458             ZZATDNN          2015     GLUCOSE 3 HR   115.0
# 459             ZZATDNN          2015  GLUCOSE FASTING   103.0
# 460            ZZDDHNGK          2018     GLUCOSE 1 HR   159.0
# 461            ZZDDHNGK          2018     GLUCOSE 2 HR   156.0
# 462            ZZDDHNGK          2018     GLUCOSE 3 HR   108.0
# 463            ZZDDHNGK          2018  GLUCOSE FASTING    79.0
# 464            ZZDDHNGK          2018  HEMOLYSIS INDEX     0.0
# 465            ZZDDHNGK          2018    ICTERIC INDEX     0.0
# 466            ZZDDHNGK          2018    LIPEMIC INDEX    13.0
# 467             ZZDKATG          2016     GLUCOSE 2 HR   164.0
# 468             ZZDKATG          2016  GLUCOSE FASTING    77.0
# 469             ZZDKATG          2016  HEMOLYSIS INDEX    15.0
# 470             ZZDKATG          2016    ICTERIC INDEX     2.0
# 471             ZZDKATG          2016    LIPEMIC INDEX    20.0
# 472              ZZDKHH          2014     GLUCOSE 2 HR   122.0
# 473              ZZDKHH          2014  GLUCOSE FASTING    84.0
# 474            ZZDODDTD          2015     GLUCOSE 1 HR   182.0
# 475            ZZDODDTD          2015     GLUCOSE 2 HR   173.0
# 476            ZZDODDTD          2015     GLUCOSE 3 HR   132.0
# 477            ZZDODDTD          2015  GLUCOSE FASTING    91.0
# 478            ZZDOKZKO          2016     GLUCOSE 1 HR   161.0
# 479            ZZDOKZKO          2016     GLUCOSE 2 HR   140.0
# 480            ZZDOKZKO          2016     GLUCOSE 3 HR    76.0
# 481            ZZDOKZKO          2016  GLUCOSE FASTING    84.0
# 482            ZZDOKZKO          2016  HEMOLYSIS INDEX     4.0
# 483            ZZDOKZKO          2016    ICTERIC INDEX     1.0
# 484            ZZDOKZKO          2016    LIPEMIC INDEX    14.0
# 485            ZZGDAHKZ          2018     GLUCOSE 1 HR   142.0
# 486            ZZGDAHKZ          2018     GLUCOSE 2 HR   131.0
# 487            ZZGDAHKZ          2018     GLUCOSE 3 HR   122.0
# 488            ZZGDAHKZ          2018  GLUCOSE FASTING    87.0
# 489              ZZHAOT          2017     GLUCOSE 1 HR   124.0
# 490              ZZHAOT          2017     GLUCOSE 2 HR   111.0
# 491              ZZHAOT          2017     GLUCOSE 3 HR    75.0
# 492              ZZHAOT          2017  GLUCOSE FASTING   103.0
# 493            ZZHOTAZA          2017     GLUCOSE 1 HR   219.0
# 494            ZZHOTAZA          2017     GLUCOSE 2 HR   178.0
# 495            ZZHOTAZA          2017     GLUCOSE 3 HR   125.0
# 496            ZZHOTAZA          2017  GLUCOSE FASTING    91.0
# 497            ZZHOTAZA          2017  HEMOLYSIS INDEX     6.0
# 498            ZZHOTAZA          2017    ICTERIC INDEX     0.0
# 499            ZZHOTAZA          2017    LIPEMIC INDEX    17.0
# 500            ZZHOTAZA          2018     GLUCOSE 2 HR   112.0
# 501            ZZHOTAZA          2018  GLUCOSE FASTING    99.0
# 502            ZZHOTAZA          2018  HEMOLYSIS INDEX     4.0
# 503            ZZHOTAZA          2018    ICTERIC INDEX     1.0
# 504            ZZHOTAZA          2018    LIPEMIC INDEX    14.0
# 505            ZZHZVVTH          2015     GLUCOSE 1 HR   129.0
# 506            ZZHZVVTH          2015     GLUCOSE 2 HR   101.0
# 507            ZZHZVVTH          2015     GLUCOSE 3 HR    94.0
# 508            ZZHZVVTH          2015  GLUCOSE FASTING    83.0
# 509            ZZKVKKZV          2018     GLUCOSE 1 HR   154.0
# 510            ZZKVKKZV          2018     GLUCOSE 2 HR   147.0
# 511            ZZKVKKZV          2018     GLUCOSE 3 HR    66.0
# 512            ZZKVKKZV          2018  GLUCOSE FASTING    93.0
# 513            ZZKVKKZV          2018  HEMOLYSIS INDEX     9.0
# 514            ZZKVKKZV          2018    ICTERIC INDEX     0.0
# 515            ZZKVKKZV          2018    LIPEMIC INDEX     9.0
# 516             ZZNGDOO          2019     GLUCOSE 1 HR   145.0
# 517             ZZNGDOO          2019     GLUCOSE 2 HR   130.0
# 518             ZZNGDOO          2019     GLUCOSE 3 HR   102.0
# 519             ZZNGDOO          2019  GLUCOSE FASTING    63.0
# 520            ZZNGZHGO          2015     GLUCOSE 1 HR   150.0
# 521            ZZNGZHGO          2015     GLUCOSE 2 HR   144.0
# 522            ZZNGZHGO          2015     GLUCOSE 3 HR   123.0
# 523            ZZNGZHGO          2015  GLUCOSE FASTING    81.0
# 524            ZZNGZHGO          2015  HEMOLYSIS INDEX     2.0
# 525            ZZNGZHGO          2015    ICTERIC INDEX     1.0
# 526            ZZNGZHGO          2015    LIPEMIC INDEX    12.0
# 527            ZZNOVDHT          2017     GLUCOSE 1 HR   171.0
# 528            ZZNOVDHT          2017     GLUCOSE 2 HR   103.0
# 529            ZZNOVDHT          2017     GLUCOSE 3 HR   102.0
# 530            ZZNOVDHT          2017  GLUCOSE FASTING    78.0
# 531            ZZNVVHVZ          2017     GLUCOSE 1 HR   183.0
# 532            ZZNVVHVZ          2017     GLUCOSE 2 HR   166.0
# 533            ZZNVVHVZ          2017     GLUCOSE 3 HR   130.0
# 534            ZZNVVHVZ          2017  GLUCOSE FASTING    90.0
# 535            ZZNVVHVZ          2017  HEMOLYSIS INDEX    27.0
# 536            ZZNVVHVZ          2017    ICTERIC INDEX     0.0
# 537            ZZNVVHVZ          2017    LIPEMIC INDEX    20.0
# 538            ZZVNOHNT          2014     GLUCOSE 1 HR   153.0
# 539            ZZVNOHNT          2014     GLUCOSE 2 HR   159.0
# 540            ZZVNOHNT          2014     GLUCOSE 3 HR    73.0
# 541            ZZVNOHNT          2014  GLUCOSE FASTING    65.0
# 542             ZZVOKKO          2015     GLUCOSE 1 HR   179.0
# 543             ZZVOKKO          2015     GLUCOSE 2 HR   163.0
# 544             ZZVOKKO          2015     GLUCOSE 3 HR    81.0
# 545             ZZVOKKO          2015  GLUCOSE FASTING    69.0>

# %%
len(pd.Series(data_bp_mean1["Deidentified_Pat_ID"].tolist()).sort_values().unique())
# Out:
# 123

# %%
new_data = data_bp_mean1.set_index(['Deidentified_Pat_ID', 'ResultedYear', 'Component']).unstack(level=2)

# %%
new_data.reset_index(inplace=True)
len(new_data)
# Out:
# 140

# %%
new_data.head()
# Out:
#           index Deidentified_Pat_ID ResultedYear       Result               \
# Component                                        GLUCOSE 1 HR GLUCOSE 2 HR
# 0             0            MNVHNHNZ         2015        175.0        142.0
# 1             1            MNVHNHNZ         2016        144.0        100.0
# 2             2              ZADTOK         2016          NaN         74.0
# 3             3             ZAVKNHD         2017         84.0        119.0
# 4             4             ZAVOOHT         2014        166.0        157.0
#
#                                                                       \
# Component GLUCOSE 3 HR GLUCOSE FASTING HEMOLYSIS INDEX ICTERIC INDEX
# 0                125.0            87.0             NaN           NaN
# 1                 97.0            88.0             NaN           NaN
# 2                  NaN            90.0            15.0           2.0
# 3                 81.0            79.0             NaN           NaN
# 4                 86.0            82.0             NaN           NaN
#
#
# Component LIPEMIC INDEX
# 0                   NaN
# 1                   NaN
# 2                  20.0
# 3                   NaN
# 4                   NaN

# %%
new_data.sort_values(["Deidentified_Pat_ID", 'ResultedYear'], inplace=True)
new_data.columns = ['in',"Deidentified_Pat_ID", 'ResultedYear','GLUCOSE 1 HR','GLUCOSE 2 HR','GLUCOSE 3 HR','GLUCOSE FASTING','HEMOLYSIS INDEX','ICTERIC INDEX','LIPEMIC INDEX']
new_data = new_data.drop_duplicates(['Deidentified_Pat_ID'], keep='last')
len(new_data)
# Out:
# 123

# %%
new_data = new_data[["Deidentified_Pat_ID",'GLUCOSE 1 HR','GLUCOSE 2 HR','GLUCOSE 3 HR','GLUCOSE FASTING','HEMOLYSIS INDEX','ICTERIC INDEX','LIPEMIC INDEX']]

# %%
new_data.head()
# Out:
#   Deidentified_Pat_ID  GLUCOSE 1 HR  GLUCOSE 2 HR  GLUCOSE 3 HR  \
# 1            MNVHNHNZ         144.0         100.0          97.0
# 2              ZADTOK           NaN          74.0           NaN
# 3             ZAVKNHD          84.0         119.0          81.0
# 6             ZAVOOHT         160.0         165.0         131.0
# 7             ZDAKGNH           NaN         172.0           NaN
#
#    GLUCOSE FASTING  HEMOLYSIS INDEX  ICTERIC INDEX  LIPEMIC INDEX
# 1             88.0              NaN            NaN            NaN
# 2             90.0             15.0            2.0           20.0
# 3             79.0              NaN            NaN            NaN
# 6             81.0              NaN            NaN            NaN
# 7             87.0              NaN            NaN            NaN

# %%
new_data.to_csv(bp_file_p, index=False)
